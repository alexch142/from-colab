# %% [markdown]
# <a href="https://colab.research.google.com/github/alexch142/from-colab/blob/main/alfabank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

plt.style.use('ggplot')  # Красивые графики
plt.rcParams['figure.figsize'] = (15, 5)  # Размер картинок

# %%
import dateutil

# %%
import datetime

# %%
# pd.read_csv(

# %%
data1 = pd.read_csv('C:\\Users\\lex\\Desktop\\тест\\40702810256000000687-26-04-20.csv',engine='python', delimiter='\t')

# %%
data1.head()
# Out:
#   statement_unid            Type_close          Date              b_date  \
# 0     ID-выписки  Признак закрытия дня  Дата выписки  Фильтр дата начала
# 1            NaN                     1    26.04.2020          26.04.2020
#
#               m_date                create_date                      Name  \
# 0  Фильтр дата конца  Дата формирования выписки  Наименование организации
# 1         26.04.2020                 27.04.2020    ООО "ЮГСПЕЦАВТОМАТИКА"
#
#                Inn                   Rch  \
# 0  ИНН организации          Счет выписки
# 1       2635073421  40702810256000000687
#
#                                             name_rch     ...      \
# 0                         Наименование счета выписки     ...
# 1  Общество с ограниченной ответственностью "Югсп...     ...
#
#                  AcceptEnd          RTerms   CollectionType  \
# 0  Окончание срока акцепта  Условие оплаты  Вид аккредитива
# 1                  0000000      с акцептом                0
#
# ...

# %%
data1.shape
# Out:
# (2, 83)

# %%
data1.columns.values
# Out:
# array(['statement_unid', 'Type_close', 'Date', 'b_date', 'm_date',
#        'create_date', 'Name', 'Inn', 'Rch', 'name_rch', 'Bik', 'Korch',
#        'Type', 'name_curr', 'bal_curr', 'bc_rur', 'bc_val', 'bd_rur',
#        'bd_val', 'sc_rur', 'Sc_val', 'Sd_rur', 'Sd_val', 'Tc_rur',
#        'Tc_val', 'Td_rur', 'Td_val', 'd_c', 'oper', 'date_oper', 'number',
#        'o_date', 'sum_rur', 'sum_val', 'plat_name', 'plat_inn', 'plat_kpp',
#        'plat_acc', 'plat_bank', 'plat_bic', 'plat_ks', 'plat_swift',
#        'pol_name', 'Pol_inn', 'pol_kpp', 'pol_acc', 'pol_bank', 'pol_bic',
#        'pol_ks', 'pol_swift', 'Post', 'TaxStatus', 'TaxKbk', 'Okato',
#        'TaxReason', 'TaxPeriod', 'TaxNumber', 'TaxDate', 'TaxType',
#        'RecBankDate', 'PartNumber', 'ParentNumber', 'ParentOperType',
#        'ParentOperDate', 'Priority', 'text70', 'Debitor_code', 'Date_val',
#        'Date_recip', 'Office', 'Reason', 'Accept', 'AcceptDays',
# ...

# %%
data1[[ 'oper',  'number',
       'o_date',  'sum_val', 'plat_name','pol_name', 'bc_rur', 'sc_rur','Sd_rur','Tc_rur','Td_rur']]
# Out:
#                   oper        number       o_date                     sum_val  \
# 0  Вид операции док-та  Номер док-та  Дата док-та  Сумма док-та, в вал. счета
# 1                   02         40621   26.04.2020                     1990,00
#
#                                            plat_name  \
# 0                                         Плательщик
# 1  Общество с ограниченной ответственностью "Югсп...
#
#                                   pol_name  \
# 0                               Получатель
# 1  ФИЛИАЛ "СТАВРОПОЛЬСКИЙ" АО "АЛЬФА-БАНК"
#
#                                    bc_rur                            sc_rur  \
# 0  Входящий ост. по кред. в руб. эквивал.  Обороты по кред. в руб. эквивал.
# 1                                26829,06                              0.00
#
#                             Sd_rur                                   Tc_rur  \
# 0  Обороты по деб. в руб. эквивал.  Исходящий ост. по кред. в руб. эквивал.
# ...

# %%
data2 = pd.read_excel('C:\\Users\\lex\\Desktop\\тест\\test_tf.xls',sep=';')

# %%
data2.head()
# Out:
#             Номер счета Идентификатор транзакции  \
# 0  40702810710000197632            TNC_180532715
# 1  40702810710000197632            TNC_180532193
# 2  40702810710000197632            TNC_180532111
# 3  40702810710000197632            TNC_180531968
# 4  40702810710000197632            TNC_180248237
#
#   Тип операции (пополнение/списание) Категория операции      Статус  \
# 0                             Credit        incomeLegal  транзакция
# 1                             Credit        incomeLegal  транзакция
# 2                             Credit        incomeLegal  транзакция
# 3                             Credit        incomeLegal  транзакция
# 4                              Debit    contragentLegal  транзакция
#
#   Дата создания операции Дата авторизации Дата транзакции  \
# 0                    NaT       2020-04-27      2020-04-27
# 1                    NaT       2020-04-27      2020-04-27
# 2                    NaT       2020-04-27      2020-04-27
# ...

# %%
data2.shape
# Out:
# (2728, 37)

# %%
#data1 = pd.read_csv('C:\\Users\\lex\\Desktop\\14.02.2018-28.04.2020.csv',encoding='utf8',engine='python',sep='; ')

# %%
#data1.head()

# %%
data2.columns.values
# Out:
# array(['Номер счета', 'Идентификатор транзакции',
#        'Тип операции (пополнение/списание)', 'Категория операции',
#        'Статус', 'Дата создания операции', 'Дата авторизации',
#        'Дата транзакции', 'Идентификатор оригинальной операции',
#        'Сумма операции в валюте операции', 'Валюта операции',
#        'Сумма в валюте счета', 'Контрагент', 'ИНН контрагента',
#        'КПП контрагента', 'Счет контрагента', 'БИК банка контрагента',
#        'Корр. счет банка контрагента', 'Наименование банка контрагента',
#        'Назначение платежа', 'Номер платежа', 'Очередность', 'Код (УИН)',
#        'Номер карты', 'MCC', 'Место совершения (Город)',
#        'Место совершения (Страна)', 'Адрес организации', 'Банк',
#        'Статус составителя расчетного документа',
#        'КБК-код бюджетной классификации', 'Код ОКТМО',
#        'Основание налогового платежа',
#        'Налоговый\xa0период/Код таможенного органа',
# ...

# %%
data_tf=data2[['Тип операции (пополнение/списание)', 'Категория операции',
       'Дата транзакции','Сумма в валюте счета', 'Контрагент','Назначение платежа']]

# %%
data2.info(verbose='true',null_counts='true')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2728 entries, 0 to 2727
# Data columns (total 37 columns):
# Номер счета                                2728 non-null object
# Идентификатор транзакции                   2728 non-null object
# Тип операции (пополнение/списание)         2728 non-null object
# Категория операции                         2728 non-null object
# Статус                                     2728 non-null object
# Дата создания операции                     362 non-null datetime64[ns]
# Дата авторизации                           2727 non-null datetime64[ns]
# Дата транзакции                            2728 non-null datetime64[ns]
# Идентификатор оригинальной операции        235 non-null float64
# Сумма операции в валюте операции           420 non-null float64
# Валюта операции                            2728 non-null int64
# Сумма в валюте счета                       2728 non-null float64
# Контрагент                                 2661 non-null object
# ...

# %%
data2.shape[0]
# Out:
# 2728

# %%
for i in range (data_tf.shape[0]):
    if data_tf['Тип операции (пополнение/списание)'][i]=='Debit':
       data_tf['Сумма в валюте счета'][i]=data_tf['Сумма в валюте счета'][i]*(-1)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2862: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data_tf[['Сумма в валюте счета']].head()
# Out:
#    Сумма в валюте счета
# 0                3000.0
# 1                3000.0
# 2                2250.0
# 3                3000.0
# 4               -2400.0

# %%
data_tf[['Сумма в валюте счета']].sum()
# Out:
# Сумма в валюте счета    162534.69
# dtype: float64

# %%
s=0
for i in range (data2.shape[0]):
    
    if data2['Тип операции (пополнение/списание)'][i]=='Credit':
       s=s+data2['Сумма в валюте счета'][i]
    
print(s)
# Out:
# 5210972.6

# %%
data_tf['Сумма в валюте счета'][data_tf['Тип операции (пополнение/списание)'] =='Credit'].sum()
# Out:
# 5210972.6000000015

# %%
data_tf['Сумма в валюте счета'][data_tf['Тип операции (пополнение/списание)'] =='Debit'].sum()
# Out:
# -5048437.910000001

# %%
data_tf[['Сумма в валюте счета']].sum()
# Out:
# Сумма в валюте счета    162534.69
# dtype: float64

# %%
data_tf.head()
# Out:
#   Тип операции (пополнение/списание) Категория операции Дата транзакции  \
# 0                             Credit        incomeLegal      2020-04-27
# 1                             Credit        incomeLegal      2020-04-27
# 2                             Credit        incomeLegal      2020-04-27
# 3                             Credit        incomeLegal      2020-04-27
# 4                              Debit    contragentLegal      2020-04-24
#
#    Сумма в валюте счета                                         Контрагент  \
# 0                3000.0  ПАО СБЕРБАНК//ВОЛОХОВА НАТАЛЬЯ НИКОЛАЕВНА//906...
# 1                3000.0  ПАО СБЕРБАНК//МАЛСУГЕНОВ ОЛЕГ ВЛАДИМИРОВИЧ//90...
# 2                2250.0  ПАО СБЕРБАНК//ЖУЙКОВА ЕВГЕНИЯ СЕРГЕЕВНА//90620...
# 3                3000.0  ПАО СБЕРБАНК//МОРОЗОВ ДМИТРИЙ ВАЛЕРЬЕВИЧ//9061...
# 4               -2400.0                           ИП Лоцман Михаил Юрьевич
#
#                                   Назначение платежа
# ...

# %%
data_tf['Год'] = data_tf['Дата транзакции'].map(lambda x: x.year)
data_tf['Месяц'] = data_tf['Дата транзакции'].map(lambda x: x.month)
data_tf['День'] = data_tf['Дата транзакции'].map(lambda x: x.day)
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data_tf = data_tf.drop(['Дата транзакции'], axis = 1)
data_tf.head()
# Out:
#   Тип операции (пополнение/списание) Категория операции  Сумма в валюте счета  \
# 0                             Credit        incomeLegal                3000.0
# 1                             Credit        incomeLegal                3000.0
# 2                             Credit        incomeLegal                2250.0
# 3                             Credit        incomeLegal                3000.0
# 4                              Debit    contragentLegal               -2400.0
#
#                                           Контрагент  \
# 0  ПАО СБЕРБАНК//ВОЛОХОВА НАТАЛЬЯ НИКОЛАЕВНА//906...
# 1  ПАО СБЕРБАНК//МАЛСУГЕНОВ ОЛЕГ ВЛАДИМИРОВИЧ//90...
# 2  ПАО СБЕРБАНК//ЖУЙКОВА ЕВГЕНИЯ СЕРГЕЕВНА//90620...
# 3  ПАО СБЕРБАНК//МОРОЗОВ ДМИТРИЙ ВАЛЕРЬЕВИЧ//9061...
# 4                           ИП Лоцман Михаил Юрьевич
#
#                                   Назначение платежа   Год  Месяц  День
# 0                                      ЗА 25/04/2020  2020      4    27
# ...

# %%
data_tf[data_tf['Контрагент']=='ПАО СБЕРБАНК//ЛОЦМАН МИХАИЛ ЮРЬЕВИЧ//348680789107//РОССИЯ 355000 КР СТАВРОПОЛЬСКИЙ Г СТАВРОПОЛЬ УЛ КАРЛА МАРКСА Д 3 К 1А КВ 112//']
# Out:
#      Тип операции (пополнение/списание) Категория операции  \
# 2483                             Credit        incomeLegal
# 2485                             Credit        incomeLegal
# 2486                             Credit        incomeLegal
# 2487                             Credit        incomeLegal
# 2488                             Credit        incomeLegal
# 2489                             Credit        incomeLegal
# 2490                             Credit        incomeLegal
# 2491                             Credit        incomeLegal
# 2492                             Credit        incomeLegal
# 2493                             Credit        incomeLegal
# 2494                             Credit        incomeLegal
# 2495                             Credit        incomeLegal
# 2496                             Credit        incomeLegal
# 2497                             Credit        incomeLegal
# 2499                             Credit        incomeLegal
# ...

# %%
data_tf['Контрагент'][2696:2698]
# Out:
# 2696    ПАО СБЕРБАНК//ЛОЦМАН МИХАИЛ ЮРЬЕВИЧ//348680789...
# 2697    ПАО СБЕРБАНК//ЛОЦМАН МИХАИЛ ЮРЬЕВИЧ//348680789...
# Name: Контрагент, dtype: object

# %%
data_tf.groupby(['Год','Месяц'])['Сумма в валюте счета'].sum().plot()

# %%
data_tf[data_tf['Контрагент'] == 'ИП Лоцман Михаил Юрьевич'].groupby('Год').agg({'Сумма в валюте счета': [min, max, sum]})
# Out:
#      Сумма в валюте счета
#                       min     max       sum
# Год
# 2018             -89075.0 -5000.0 -251235.0
# 2019            -167870.0 -1400.0 -721294.0
# 2020            -210000.0 -2000.0 -354019.0

# %%
#Запускать перед верхней строчкой!!!!!
data_tf[data_tf['Контрагент'] == 'ИП Лоцман Михаил Юрьевич'].groupby(['Год','Месяц']).agg({'Сумма в валюте счета': 'sum'})
# Out:
#             Сумма в валюте счета
# Год  Месяц
# 2018 3                  -15000.0
#      5                   -5000.0
#      10                 -71100.0
#      12                -160135.0
# 2019 1                   -5350.0
#      2                 -122735.0
#      3                 -167870.0
#      4                  -32780.0
#      5                  -47583.0
#      7                   -3650.0
#      8                   -7500.0
#      9                  -28800.0
#      11                 -51106.5
#      12                -253919.5
# 2020 1                  -20000.0
#      2                  -30000.0
#      3                  -82119.0
#      4                 -221900.0
