       [0.1408,0.1398,0.1398,0.1388,0.1388,0.1388,0.1388,0.1388],
       [0.1437,0.1427,0.1427,0.1417,0.1408,0.1417,0.1398,0.1388],
       [0.1417,0.1417,0.1437,0.1437,0.1427,0.1408,0.1408,0.1388]
      ] 


off_2 = [[0.1398,0.1388,0.1398,0.13880,0.1388,0.1398,0.1398,0.1378],
         [0.1369,0.1369,0.1398,0.13880,0.1398,0.1398,0.1398,0.1398],
         [0.1398,0.1398,0.1398,0.1398,0.1408,0.1388,0.14080,0.1398],
         [0.1417,0.1408,0.1398,0.13980,0.1398,0.1398,0.1388,0.1398],
         [0.1388,0.1398,0.1398,0.1398,0.1398,0.13980,0.1398,0.1408],
         [0.1388,0.13980,0.1398,0.1398,0.1398,0.1388,0.1388,0.1398],
         [0.1408,0.14080,0.1408,0.1398,0.1398,0.1398,0.1369,0.1369],
         [0.1408,0.1398,0.1398,0.1388,0.1388,0.1388,0.1398,0.13880],
         [0.1378,0.1398,0.1398,0.1398,0.1388,0.1398,0.1398,0.13978],
         [0.1398,0.14080,0.1408,0.1398,0.1398,0.1398,0.1398,0.1398],
         [0.1417,0.1398,0.1398,0.1398,0.1388,0.1398,0.13980,0.1369]
        ]

# %%
for i in range(7):
  print(sum(on_2[i])/8)
# Out:
# 0.1400375
# 0.1421
# 0.14345
# 0.14382499999999998
# 0.1431
# 0.1413625
# 0.14015000000000002

# %%
for i in range(7):
  print(sum(off_2[i])/8)
# Out:
# 0.13917500000000002
# 0.13895000000000002
# 0.13992500000000002
# 0.1400375
# 0.1398
# 0.13942500000000002
# 0.13945000000000002

# %%
for i in range(7):
  print(sum(off_1[i])/8)
# Out:
# 0.132224975
# 0.1325624825
# 0.13267499249999998
# 0.132449995
# 0.13289999
# 0.13268749500000002
# 0.1325624825

# %%
for i in range(7):
  print(sum(on_1[i])/8)
# Out:
# 0.13244998749999998
# 0.11608750000000001
# 0.11265
# 0.13365000000000002
# 0.138825
# 0.1556625
# 0.16288736250000002

# %%
def scoring (target):
 for i in range(7):
    a= min(target[i])
    b= max(target[i])
    c= sum(target[i])/8
    print('min= %f, max= %f, mean= %f'%(a,b,c))

# %%
scoring(off_1)
# Out:
# min= 0.132000, max= 0.132900, mean= 0.132225
# min= 0.132000, max= 0.132900, mean= 0.132562
# min= 0.132000, max= 0.132900, mean= 0.132675
# min= 0.132000, max= 0.132900, mean= 0.132450
# min= 0.132900, max= 0.132900, mean= 0.132900
# min= 0.132000, max= 0.133900, mean= 0.132687
# min= 0.132000, max= 0.132900, mean= 0.132562
